# %%
#Group H
#We want to import python compatible drivers for SQL Connection
import pyodbc

#Shows the list of drivers as part of pyodoc
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'SQL Server Native Client 11.0',
#  'ODBC Driver 17 for SQL Server',
#  'Microsoft Access Driver (*.mdb, *.accdb)',
#  'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'Microsoft Access Text Driver (*.txt, *.csv)',
#  'SQL Server Native Client RDA 11.0']

# %%
#Creating a connection using our pyton client code against the Server
conn = pyodbc.connect('Driver={ODBC Driver 17 for SQL Server};'
                      'Server=LAPTOP-2VM8P06F\SQLSERVER2019;'
                      'Database=AdventureWorks2019;'
                      'Trusted_Connection=yes;')
print(conn)
# Out:
# <pyodbc.Connection object at 0x000001C934E54B90>

# %%
#Read Operation
query2 ="SELECT * FROM Person.Person"
cursor = conn.cursor();
cursor.execute(query2);
data1 = cursor.fetchall()
data1
# Out:
# [(1, 'EM', False, None, 'Ken', 'J', 'Sánchez', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '92C4279F-1207-48A3-8448-4636514EB7E2', datetime.datetime(2009, 1, 7, 0, 0)),
#  (2, 'EM', False, None, 'Terri', 'Lee', 'Duffy', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'D8763459-8AA8-47CC-AFF7-C9079AF79033', datetime.datetime(2008, 1, 24, 0, 0)),
#  (3, 'EM', False, None, 'Roberto', None, 'Tamburello', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'E1A2555E-0828-434B-A33B-6F38136A37DE', datetime.datetime(2007, 11, 4, 0, 0)),
#  (4, 'EM', False, None, 'Rob', None, 'Walters', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'F2D7CE06-38B3-4357-805B-F4B6B71C01FF', datetime.datetime(2007, 11, 28, 0, 0)),
#  (5, 'EM', False, 'Ms.', 'Gail', 'A', 'Erickson', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'F3A3F6B4-AE3B-430C-A754-9F2231BA6FEF', datetime.datetime(2007, 12, 30, 0, 0)),
#  (6, 'EM', False, 'Mr.', 'Jossef', 'H', 'Goldberg', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '0DEA28FD-EFFE-482A-AFD3-B7E8F199D56F', datetime.datetime(2013, 12, 16, 0, 0)),
#  (7, 'EM', False, None, 'Dylan', 'A', 'Miller', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'C45E8AB8-01BE-4B76-B215-820C8368181A', datetime.datetime(2009, 2, 1, 0, 0)),
#  (8, 'EM', False, None, 'Diane', 'L', 'Margheim', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'A948E590-4A56-45A9-BC9A-160A1CC9D990', datetime.datetime(2008, 12, 22, 0, 0)),
#  (9, 'EM', False, None, 'Gigi', 'N', 'Matthew', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '5FC28C0E-6D36-4252-9846-05CAA0B1F6C5', datetime.datetime(2009, 1, 9, 0, 0)),
#  (10, 'EM', False, None, 'Michael', None, 'Raheem', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'CA2C740E-75B2-420C-9D4B-E3CBC6609604', datetime.datetime(2009, 4, 26, 0, 0)),
#  (11, 'EM', False, None, 'Ovidiu', 'V', 'Cracium', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'D2CC2577-EF6B-4408-BD8C-747337FE5645', datetime.datetime(2010, 11, 28, 0, 0)),
#  (12, 'EM', False, None, 'Thierry', 'B', "D'Hers", None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'FA263C7F-600D-4E89-8DCD-0978F3530F5F', datetime.datetime(2007, 12, 4, 0, 0)),
#  (13, 'EM', False, 'Ms.', 'Janice', 'M', 'Galvin', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '34EB99E0-7042-4DC1-A2FD-BDA290FF0E07', datetime.datetime(2010, 12, 16, 0, 0)),
#  (14, 'EM', False, None, 'Michael', 'I', 'Sullivan', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '9A7501DE-5CAF-4700-AB07-CC81102BB696', datetime.datetime(2010, 12, 23, 0, 0)),
#  (15, 'EM', False, None, 'Sharon', 'B', 'Salavaria', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'BEBA63CB-13F1-4B76-A3DE-FE9AC283A94C', datetime.datetime(2011, 1, 11, 0, 0)),
#  (16, 'EM', False, None, 'David', 'M', 'Bradley', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '2CC8BA72-5DBB-497F-B941-775517993638', datetime.datetime(2007, 12, 13, 0, 0)),
#  (17, 'EM', False, None, 'Kevin', 'F', 'Brown', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '9EE4713E-B3D8-4409-BC5E-DEC62497F43A', datetime.datetime(2007, 1, 19, 0, 0)),
#  (18, 'EM', False, None, 'John', 'L', 'Wood', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'FE21BDA7-9327-4D13-89CC-8CA5CEE8F21E', datetime.datetime(2011, 1, 31, 0, 0)),
#  (19, 'EM', False, None, 'Mary', 'A', 'Dempsey', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '36F04305-6769-4E61-9143-048B2B7AFA20', datetime.datetime(2011, 2, 7, 0, 0)),
#  (20, 'EM', False, None, 'Wanida', 'M', 'Benshoof', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '1E7E56F4-A583-4E3F-A3FE-BA8A71096D10', datetime.datetime(2010, 12, 31, 0, 0)),
#  (21, 'EM', False, None, 'Terry', 'J', 'Eminhizer', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '6A288FE0-D9CB-4DA2-BEEA-51370220490C', datetime.datetime(2009, 2, 23, 0, 0)),
#  (22, 'EM', False, None, 'Sariya', 'E', 'Harnpadoungsataya', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '276E0EB5-0CE7-443F-987F-B7EF293C0930', datetime.datetime(2008, 12, 5, 0, 0)),
#  (23, 'EM', False, None, 'Mary', 'E', 'Gibson', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'B10CF8EB-5589-4A81-B1BD-051C5759CE06', datetime.datetime(2009, 1, 5, 0, 0)),
#  (24, 'EM', False, 'Ms.', 'Jill', 'A', 'Williams', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '3F605060-96AD-4201-9BE2-BFE7A3C4E468', datetime.datetime(2009, 1, 11, 0, 0)),
#  (25, 'EM', False, None, 'James', 'R', 'Hamilton', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '423FE59B-7975-4A7E-B8D2-87105C286D4C', datetime.datetime(2009, 1, 27, 0, 0)),
#  (26, 'EM', False, None, 'Peter', 'J', 'Krebs', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '6F32F507-290E-4A96-A045-F445EAE4337F', datetime.datetime(2008, 11, 24, 0, 0)),
#  (27, 'EM', False, None, 'Jo', 'A', 'Brown', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'EDD8ADD6-F7FD-4086-BFDC-B4FD3E6AD8D7', datetime.datetime(2008, 2, 20, 0, 0)),
#  (28, 'EM', False, None, 'Guy', 'R', 'Gilbert', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'D366A33A-8EDE-42BD-BF79-3E7FB9713FE1', datetime.datetime(2006, 6, 23, 0, 0)),
#  (29, 'EM', False, None, 'Mark', 'K', 'McArthur', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '667FA3BA-B877-4BCC-A752-E461040E2DDD', datetime.datetime(2009, 1, 16, 0, 0)),
#  (30, 'EM', False, None, 'Britta', 'L', 'Simon', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '5090C9A8-E39E-4A4D-9133-14E7CF07998B', datetime.datetime(2009, 1, 22, 0, 0)),
#  (31, 'EM', False, None, 'Margie', 'W', 'Shoop', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '5EA8A3DA-7BEA-4ADC-85F5-C934E2033825', datetime.datetime(2008, 12, 28, 0, 0)),
#  (32, 'EM', False, None, 'Rebecca', 'A', 'Laszlo', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '686BD5AF-6F30-4633-944B-3C1916CB4CA2', datetime.datetime(2008, 12, 22, 0, 0)),
#  (33, 'EM', False, None, 'Annik', 'O', 'Stahl', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'BFA2BDC8-208A-447B-8A4E-72A215E9E134', datetime.datetime(2008, 12, 10, 0, 0)),
#  (34, 'EM', False, None, 'Suchitra', 'O', 'Mohan', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '7E239D8B-00BF-42D6-AC6B-4EA718DBC2B3', datetime.datetime(2009, 2, 9, 0, 0)),
#  (35, 'EM', False, None, 'Brandon', 'G', 'Heidepriem', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '4CC8EDC2-5502-4550-8089-9B3CC6006490', datetime.datetime(2009, 2, 1, 0, 0)),
#  (36, 'EM', False, None, 'Jose', 'R', 'Lugo', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '54655E98-B81A-4041-8FA4-9349C018521F', datetime.datetime(2009, 2, 3, 0, 0)),
#  (37, 'EM', False, None, 'Chris', 'O', 'Okelberry', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '5B16CA18-703B-48E8-AB3E-CA158C854808', datetime.datetime(2009, 2, 28, 0, 0)),
#  (38, 'EM', False, None, 'Kim', 'B', 'Abercrombie', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '9A2163B3-2F4D-4F9A-91BD-07D326140F9C', datetime.datetime(2010, 1, 9, 0, 0)),
#  (39, 'EM', False, None, 'Ed', 'R', 'Dudenhoefer', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '83C88383-9C3E-42C5-AE09-965B5F9EF5B1', datetime.datetime(2010, 1, 29, 0, 0)),
#  (40, 'EM', False, None, 'JoLynn', 'M', 'Dobney', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'E8E5C9DA-F808-4439-BF5C-B28236BB8467', datetime.datetime(2007, 12, 19, 0, 0)),
#  (41, 'EM', False, None, 'Bryan', None, 'Baker', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'A32E8274-08DC-4596-AB1F-BA6263CBC676', datetime.datetime(2009, 1, 14, 0, 0)),
#  (42, 'EM', False, None, 'James', 'D', 'Kramer', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'F4F040E0-02A0-4905-B964-2E894D0F0B94', datetime.datetime(2008, 12, 20, 0, 0)),
#  (43, 'EM', False, None, 'Nancy', 'A', 'Anderson', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '0681C8F9-D2EC-47D9-9BD4-751B14EAED50', datetime.datetime(2008, 12, 26, 0, 0)),
#  (44, 'EM', False, None, 'Simon', 'D', 'Rapier', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'FF8EDBFC-A9A3-4C5D-8AFF-DF4D6F18DAFF', datetime.datetime(2008, 12, 1, 0, 0)),
#  (45, 'EM', False, None, 'Thomas', 'R', 'Michaels', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '2CAF9ADC-7A33-48CF-B4B7-3C57D9DE39C4', datetime.datetime(2009, 2, 19, 0, 0)),
#  (46, 'EM', False, None, 'Eugene', 'O', 'Kogan', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'FB0068EA-49D4-4E82-9895-2680CF59385E', datetime.datetime(2009, 2, 1, 0, 0)),
#  (47, 'EM', False, None, 'Andrew', 'R', 'Hill', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'B6439F4F-E57D-4293-B0C8-8919591055A3', datetime.datetime(2009, 2, 15, 0, 0)),
#  (48, 'EM', False, None, 'Ruth', 'Ann', 'Ellerbrock', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '9BE35B50-2024-4785-9393-7C7AB8D9634D', datetime.datetime(2007, 12, 30, 0, 0)),
#  (49, 'EM', False, None, 'Barry', 'K', 'Johnson', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'CB28BE2E-DE93-4409-BACE-DF6042D04815', datetime.datetime(2013, 11, 29, 0, 0)),
#  (50, 'EM', False, None, 'Sidney', 'M', 'Higa', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'A20BB9F5-3BBB-4AB6-9BFA-6AED32C30204', datetime.datetime(2008, 1, 26, 0, 0)),
#  (51, 'EM', False, None, 'Jeffrey', 'L', 'Ford', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '293DF609-2FA3-4C00-A891-ACE08661FE70', datetime.datetime(2008, 2, 13, 0, 0)),
#  (52, 'EM', False, None, 'Doris', 'M', 'Hartwig', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '075AB67F-BFBD-4433-B33E-C65B2C045B6B', datetime.datetime(2014, 1, 31, 0, 0)),
#  (53, 'EM', False, None, 'Diane', 'R', 'Glimp', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '9EA27F41-36BB-4456-A506-2B87C416FB0C', datetime.datetime(2008, 3, 21, 0, 0)),
#  (54, 'EM', False, None, 'Bonnie', 'N', 'Kearney', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'AB066D28-404A-436E-A17A-789D7F2638D3', datetime.datetime(2009, 12, 25, 0, 0)),
#  (55, 'EM', False, None, 'Taylor', 'R', 'Maxwell', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '9F81714B-0C9C-43C3-8DF5-180CB0A42D40', datetime.datetime(2013, 12, 31, 0, 0)),
#  (56, 'EM', False, None, 'Denise', 'H', 'Smith', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '77F4AC33-E165-49D7-BC6A-F3C2DC069C9B', datetime.datetime(2009, 1, 29, 0, 0)),
#  (57, 'EM', False, None, 'Frank', 'T', 'Miller', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '05516FB2-586E-43F5-A87C-5E236F8DB8AD', datetime.datetime(2009, 2, 16, 0, 0)),
#  (58, 'EM', False, None, 'Kendall', 'C', 'Keil', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'CA8D648A-166B-4D61-9AE0-A0B1FFECFB1B', datetime.datetime(2008, 11, 28, 0, 0)),
#  (59, 'EM', False, None, 'Bob', 'N', 'Hohman', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '6384295C-C932-47C0-8E97-71D94F83CD31', datetime.datetime(2008, 12, 17, 0, 0)),
#  (60, 'EM', False, None, 'Pete', 'C', 'Male', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '0AEB5713-8BB0-4B8D-BF81-777158E5FF09', datetime.datetime(2009, 1, 4, 0, 0)),
#  (61, 'EM', False, None, 'Diane', 'H', 'Tibbott', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'E054FFC1-258C-4DA4-B2C1-40E155F4C88B', datetime.datetime(2009, 1, 11, 0, 0)),
#  (62, 'EM', False, None, 'John', 'T', 'Campbell', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'F5A4CC1B-AEFA-46CA-8888-2CA1C6D4034B', datetime.datetime(2014, 2, 7, 0, 0)),
#  (63, 'EM', False, None, 'Maciej', 'W', 'Dusza', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '611D56EB-C29D-4F90-A5C6-1B3B2D44E5F8', datetime.datetime(2010, 1, 22, 0, 0)),
#  (64, 'EM', False, None, 'Michael', 'J', 'Zwilling', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'DCC5AA7B-C09A-47A5-86A2-90D88191EBE6', datetime.datetime(2010, 2, 16, 0, 0)),
#  (65, 'EM', False, None, 'Randy', 'T', 'Reeves', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'D988D8E0-C335-4F4C-9ED9-199FEB7FD4A7', datetime.datetime(2010, 2, 16, 0, 0)),
#  (66, 'EM', False, None, 'Karan', 'R', 'Khanna', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '58C97993-7491-49EE-BFDD-CD80CE2C922A', datetime.datetime(2009, 12, 15, 0, 0)),
#  (67, 'EM', False, None, 'Jay', 'G', 'Adams', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '2FE289A7-CE57-49E5-BE61-3E6580D22EA6', datetime.datetime(2009, 2, 26, 0, 0)),
#  (68, 'EM', False, None, 'Charles', 'B', 'Fitzgerald', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '1E7CD457-A854-4D68-ACFB-3D752EEBD231', datetime.datetime(2009, 11, 26, 0, 0)),
#  (69, 'EM', False, None, 'Steve', 'F', 'Masters', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '85F55758-54C4-4048-ACBE-BD9515669122', datetime.datetime(2009, 2, 8, 0, 0)),
#  (70, 'EM', False, None, 'David', 'J', 'Ortiz', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '60245B9F-EABD-48CF-9FA9-C5DD48BCB3DF', datetime.datetime(2008, 12, 8, 0, 0)),
#  (71, 'EM', False, None, 'Michael', 'Sean', 'Ray', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'CA42A0B4-C068-4C75-A8A3-DE8953760927', datetime.datetime(2009, 2, 8, 0, 0)),
#  (72, 'EM', False, None, 'Steven', 'T', 'Selikoff', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '7455FEFF-9238-4C29-819F-A4DF6508C0F8', datetime.datetime(2008, 11, 24, 0, 0)),
#  (73, 'EM', False, None, 'Carole', 'M', 'Poland', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '4EE4FAF4-9C85-4022-B07F-956F1C5595D5', datetime.datetime(2008, 12, 12, 0, 0)),
#  (74, 'EM', False, None, 'Bjorn', 'M', 'Rettig', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '056617D9-E65F-41C7-98AF-9C14C4569652', datetime.datetime(2008, 12, 31, 0, 0)),
#  (75, 'EM', False, None, 'Michiko', 'F', 'Osada', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '670CE5A5-2B86-4AD7-AEF5-DF2AAAC4A6AB', datetime.datetime(2009, 1, 19, 0, 0)),
#  (76, 'EM', False, None, 'Carol', 'M', 'Philips', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '7AC771B3-347A-49FA-9298-487B02FA359D', datetime.datetime(2009, 2, 5, 0, 0)),
#  (77, 'EM', False, None, 'Merav', 'A', 'Netz', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'F9427582-FD1B-45DE-922D-2C2C58CEA0F7', datetime.datetime(2009, 2, 24, 0, 0)),
#  (78, 'EM', False, None, 'Reuben', 'H', "D'sa", None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'AEBEAA5B-D861-4703-A959-6D0F6F4CDF74', datetime.datetime(2008, 12, 8, 0, 0)),
#  (79, 'EM', False, None, 'Eric', 'L', 'Brown', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'D0EFAF3A-04DC-442F-9AA1-926C38105241', datetime.datetime(2010, 1, 17, 0, 0)),
#  (80, 'EM', False, None, 'Sandeep', 'P', 'Kaliyath', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '7E5B79F9-5B7A-41DC-850F-23B4764B5161', datetime.datetime(2010, 1, 10, 0, 0)),
#  (81, 'EM', False, None, 'Mihail', 'U', 'Frintu', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '1062CA88-998C-472C-8BD5-9F3D4BC4D2FB', datetime.datetime(2009, 12, 22, 0, 0)),
#  (82, 'EM', False, None, 'Jack', 'T', 'Creasey', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'ED8B39AF-5DA5-405F-8C38-A6C3AC25CA1B', datetime.datetime(2010, 2, 24, 0, 0)),
#  (83, 'EM', False, None, 'Patrick', 'M', 'Cook', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'F03E1512-0DC2-4329-8F21-6C5DBB9996F3', datetime.datetime(2010, 2, 5, 0, 0)),
#  (84, 'EM', False, None, 'Frank', 'R', 'Martinez', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'B66AB99E-691C-4CAC-B62D-579816800BFA', datetime.datetime(2010, 1, 29, 0, 0)),
#  (85, 'EM', False, None, 'Brian', 'Richard', 'Goldstein', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '61CE0232-4144-48AE-BA3B-1D509505F106', datetime.datetime(2009, 12, 4, 0, 0)),
#  (86, 'EM', False, None, 'Ryan', 'L', 'Cornelsen', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '0E3F7512-87A6-4C0D-9E02-30919A75BF60', datetime.datetime(2008, 12, 29, 0, 0)),
#  (87, 'EM', False, None, 'Cristian', 'K', 'Petculescu', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '45FE0378-ED23-4D24-A5F5-11B10B402980', datetime.datetime(2008, 12, 15, 0, 0)),
#  (88, 'EM', False, None, 'Betsy', 'A', 'Stadick', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'C214AB1E-A07E-4A62-9033-19DDE0DE1937', datetime.datetime(2009, 12, 11, 0, 0)),
#  (89, 'EM', False, None, 'Patrick', 'C', 'Wedge', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'CD334AC3-EE11-4999-BBA1-7F33DE161124', datetime.datetime(2010, 1, 25, 0, 0)),
#  (90, 'EM', False, None, 'Danielle', 'C', 'Tiedt', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '852A07EE-1D24-4810-8121-365DAB884C8D', datetime.datetime(2010, 2, 13, 0, 0)),
#  (91, 'EM', False, None, 'Kimberly', 'B', 'Zimmerman', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '67647D8C-C685-4704-81B7-AE1087CC2C6D', datetime.datetime(2010, 1, 5, 0, 0)),
#  (92, 'EM', False, None, 'Tom', 'M', 'Vande Velde', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'A36DA26B-29BA-4627-9731-134D65A53143', datetime.datetime(2010, 3, 3, 0, 0)),
#  (93, 'EM', False, None, 'Kok-Ho', 'T', 'Loh', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '3E4AE757-8C3E-47CC-BC20-528CCF271E3D', datetime.datetime(2008, 12, 20, 0, 0)),
#  (94, 'EM', False, None, 'Russell', None, 'Hunter', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '288EF549-203C-439C-A6B2-32FD822327FF', datetime.datetime(2008, 12, 5, 0, 0)),
#  (95, 'EM', False, None, 'Jim', 'H', 'Scardelis', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'A45F89BB-9748-41F8-9FAA-A5D76DF4B029', datetime.datetime(2008, 12, 12, 0, 0)),
#  (96, 'EM', False, None, 'Elizabeth', 'I', 'Keyser', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'CB9A2A0C-68E5-475B-9D6D-EBD548FE5B9C', datetime.datetime(2009, 2, 23, 0, 0)),
#  (97, 'EM', False, None, 'Mandar', 'H', 'Samant', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '907AE318-9FF7-4B56-B52B-5FDCA7BF8A62', datetime.datetime(2009, 2, 3, 0, 0)),
#  (98, 'EM', False, None, 'Sameer', 'A', 'Tejani', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'F19BE575-4A2E-413D-9BE9-0AF4B75C6FCD', datetime.datetime(2009, 2, 4, 0, 0)),
#  (99, 'EM', False, None, 'Nuan', None, 'Yu', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '938FCD64-E06D-453C-9E70-BFE41753557B', datetime.datetime(2008, 12, 30, 0, 0)),
#  (100, 'EM', False, None, 'Lolan', 'B', 'Song', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'DCD41870-A67B-4D7F-B874-92C6854E1D0D', datetime.datetime(2009, 1, 5, 0, 0)),
#  (101, 'EM', False, None, 'Houman', 'N', 'Pournasseh', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '14E39720-994D-42C0-A26D-7877BB264FF5', datetime.datetime(2009, 1, 18, 0, 0)),
#  (102, 'EM', False, None, 'Zheng', 'W', 'Mu', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '17D15AE1-FB50-4303-A509-24C6C553C17D', datetime.datetime(2008, 11, 26, 0, 0)),
#  (103, 'EM', False, None, 'Ebru', 'N', 'Ersan', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '64A9674E-9625-4EF2-8F4D-357390735C08', datetime.datetime(2009, 11, 29, 0, 0)),
#  (104, 'EM', False, None, 'Mary', 'R', 'Baker', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '9E450675-B7F1-47C1-BB64-95E998B57ED4', datetime.datetime(2009, 12, 18, 0, 0)),
#  (105, 'EM', False, None, 'Kevin', 'M', 'Homer', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '1D1C9D2A-EA15-409C-8E32-8F5C6F8F286A', datetime.datetime(2009, 12, 18, 0, 0)),
#  (106, 'EM', False, None, 'John', 'T', 'Kane', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '4C117C8F-07C6-4B4E-A7D0-B8AD58EED8AE', datetime.datetime(2010, 2, 20, 0, 0)),
#  (107, 'EM', False, None, 'Christopher', 'E', 'Hill', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'A066751C-B57F-4186-8219-6652AE1189B1', datetime.datetime(2010, 2, 1, 0, 0)),
#  (108, 'EM', False, None, 'Jinghao', 'K', 'Liu', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'DD35EB13-6D4F-4C82-B33C-D693090722B6', datetime.datetime(2008, 12, 1, 0, 0)),
#  (109, 'EM', False, None, 'Alice', 'O', 'Ciccu', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'B5836E66-4251-4D4D-8F49-8E6D9E3C9D64', datetime.datetime(2008, 11, 30, 0, 0)),
#  (110, 'EM', False, None, 'Jun', 'T', 'Cao', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '20BDFF3B-3561-482B-B02D-DA9B6183B6D9', datetime.datetime(2008, 12, 7, 0, 0)),
#  (111, 'EM', False, None, 'Suroor', 'R', 'Fatima', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '62C97C5B-5CAB-42C6-813D-C0C75BBBFD7B', datetime.datetime(2008, 12, 10, 0, 0)),
#  (112, 'EM', False, None, 'John', 'P', 'Evans', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'FCFA001C-D5BC-455F-9124-21290B4A5304', datetime.datetime(2008, 12, 25, 0, 0)),
#  (113, 'EM', False, None, 'Linda', 'K', 'Moschell', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '1552D700-1E1C-4725-8074-D8D7D9A49B0E', datetime.datetime(2008, 12, 18, 0, 0)),
#  (114, 'EM', False, None, 'Mindaugas', 'J', 'Krapauskas', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '7C623D80-0A62-42DE-A355-24715A7160C6', datetime.datetime(2009, 1, 6, 0, 0)),
#  (115, 'EM', False, None, 'Angela', 'W', 'Barbariol', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '8E6ADFD0-2FE0-4EB9-93F2-A04FD877F6DC', datetime.datetime(2009, 1, 13, 0, 0)),
#  (116, 'EM', False, None, 'Michael', 'W', 'Patten', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'C31D89BE-1DB6-495B-8699-4669E5FA4B9D', datetime.datetime(2009, 1, 24, 0, 0)),
#  (117, 'EM', False, None, 'Chad', 'W', 'Niswonger', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '1CAC3A75-34AB-45C1-B9F1-7CAA44C76A75', datetime.datetime(2009, 2, 11, 0, 0)),
#  (118, 'EM', False, None, 'Don', 'L', 'Hall', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'F369194E-2FF0-4E61-97A7-B821F8B2BAED', datetime.datetime(2009, 2, 6, 0, 0)),
#  (119, 'EM', False, None, 'Michael', 'T', 'Entin', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '7533C47D-8E8F-40AC-8383-CF3DF57E3D84', datetime.datetime(2009, 2, 18, 0, 0)),
#  (120, 'EM', False, None, 'Kitti', 'H', 'Lertpiriyasuwat', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'BFADC42C-0D0E-4BDA-94B7-B14E89F5FC69', datetime.datetime(2009, 2, 25, 0, 0)),
#  (121, 'EM', False, None, 'Pilar', 'G', 'Ackerman', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '81F50324-D0B5-4EA5-8B20-F99D46572C76', datetime.datetime(2008, 12, 26, 0, 0)),
#  (122, 'EM', False, None, 'Susan', 'W', 'Eaton', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '84C723AC-F07F-4299-89B1-FAABB9CA47FC', datetime.datetime(2008, 11, 30, 0, 0)),
#  (123, 'EM', False, None, 'Vamsi', 'N', 'Kuppa', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '37154EFE-002F-4D85-A84B-A8B1FF714BC6', datetime.datetime(2008, 11, 30, 0, 0)),
#  (124, 'EM', False, None, 'Kim', 'T', 'Ralls', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '7AB39816-FF5A-4F3D-A3DC-88D906EC054F', datetime.datetime(2008, 12, 19, 0, 0)),
#  (125, 'EM', False, None, 'Matthias', 'T', 'Berndt', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '318BF718-6CCC-4F26-AC81-00EAF17B1BFE', datetime.datetime(2009, 1, 13, 0, 0)),
#  (126, 'EM', False, None, 'Jimmy', 'T', 'Bischoff', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '52182904-CFAF-4B2D-8D77-268DE7AB5DA4', datetime.datetime(2009, 2, 19, 0, 0)),
#  (127, 'EM', False, None, 'David', 'P', 'Hamilton', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'D6532F6D-A832-4266-B0F0-2F874F5A85BA', datetime.datetime(2008, 12, 27, 0, 0)),
#  (128, 'EM', False, None, 'Paul', 'B', 'Komosinski', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'E4145F40-88D2-43F4-A018-9BFB38D6D9FF', datetime.datetime(2008, 11, 27, 0, 0)),
#  (129, 'EM', False, None, 'Gary', 'W', 'Yukish', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '09EA8640-ED99-4205-9433-078F1D81D221', datetime.datetime(2008, 12, 15, 0, 0)),
#  (130, 'EM', False, None, 'Rob', 'T', 'Caron', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '909F01EF-2F6D-44DD-AF8D-1553BED7EACF', datetime.datetime(2009, 2, 6, 0, 0)),
#  (131, 'EM', False, None, 'Baris', 'F', 'Cetinok', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'BA03C1A4-0577-44F5-BFBC-FC701C007F13', datetime.datetime(2009, 2, 8, 0, 0)),
#  (132, 'EM', False, None, 'Nicole', 'B', 'Holliday', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'F101C5EE-17B1-4FB0-9CAE-4A88694CEEAA', datetime.datetime(2009, 2, 15, 0, 0)),
#  (133, 'EM', False, None, 'Michael', 'L', 'Rothkugel', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'EE04F4CB-977A-48D0-ACB4-D89172FD5AE2', datetime.datetime(2009, 1, 3, 0, 0)),
#  (134, 'EM', False, None, 'Eric', None, 'Gubbels', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '4A9AC912-9E22-47B7-B126-5F3B576A430E', datetime.datetime(2009, 1, 7, 0, 0)),
#  (135, 'EM', False, None, 'Ivo', 'William', 'Salmre', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'DFA4B008-D83F-4828-AAC6-449E683909F5', datetime.datetime(2008, 11, 27, 0, 0)),
#  (136, 'EM', False, None, 'Sylvester', 'A', 'Valdez', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '6152BEC3-BB11-43AA-B691-9881CE6DD3F3', datetime.datetime(2009, 12, 4, 0, 0)),
#  (137, 'EM', False, None, 'Anibal', 'T', 'Sousa', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '9B75A538-958C-4C91-987A-B9BCCE683E8A', datetime.datetime(2009, 2, 16, 0, 0)),
#  (138, 'EM', False, None, 'Samantha', 'H', 'Smith', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '11EF6F0A-29B6-4541-82F0-2E7A35179E48', datetime.datetime(2009, 1, 28, 0, 0)),
#  (139, 'EM', False, 'Mr.', 'Hung-Fu', 'T', 'Ting', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '739C7553-13E5-4F36-86F6-4775645547AE', datetime.datetime(2009, 12, 30, 0, 0)),
#  (140, 'EM', False, None, 'Prasanna', 'E', 'Samarawickrama', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'E8673E92-31F6-42F4-A65C-A595D3F899F6', datetime.datetime(2010, 1, 15, 0, 0)),
#  (141, 'EM', False, None, 'Min', 'G', 'Su', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '3BB0243E-11E3-4E5C-8DB5-6B927C71432E', datetime.datetime(2010, 1, 17, 0, 0)),
#  (142, 'EM', False, None, 'Olinda', 'C', 'Turner', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'BF741CEC-34E0-4B44-99C2-E0382FCD9E8E', datetime.datetime(2010, 2, 25, 0, 0)),
#  (143, 'EM', False, None, 'Krishna', None, 'Sunkammurali', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '442C8270-1E84-47C5-A621-AF10CF1B3546', datetime.datetime(2010, 2, 6, 0, 0)),
#  (144, 'EM', False, None, 'Paul', 'R', 'Singh', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'BA4C0109-A2A4-4595-A357-38A64B643E3C', datetime.datetime(2009, 1, 10, 0, 0)),
#  (145, 'EM', False, None, 'Cynthia', 'S', 'Randall', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'F0C15AD6-4CFF-4931-A216-49B635596043', datetime.datetime(2009, 1, 20, 0, 0)),
#  (146, 'EM', False, None, 'Jian Shuo', None, 'Wang', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '009EBB72-9173-4AA9-920E-B578F3C927DE', datetime.datetime(2008, 11, 30, 0, 0)),
#  (147, 'EM', False, None, 'Sandra', None, 'Reátegui Alayo', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'B07FA8A6-A056-48AB-91F8-318C6C87B502', datetime.datetime(2008, 12, 19, 0, 0)),
#  (148, 'EM', False, None, 'Jason', 'M', 'Watters', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '00D61032-0D0E-41E3-8F37-B5987C8D5087', datetime.datetime(2009, 1, 7, 0, 0)),
#  (149, 'EM', False, None, 'Andy', 'M', 'Ruth', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '9CFDF60A-083A-44DC-AFE2-D578C76FD55A', datetime.datetime(2009, 1, 24, 0, 0)),
#  (150, 'EM', False, None, 'Michael', 'T', 'Vanderhyde', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '944AE1F8-E154-4752-9A24-8E8FE85156F3', datetime.datetime(2009, 2, 19, 0, 0)),
#  (151, 'EM', False, None, 'Rostislav', 'E', 'Shabalin', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'FAA146E7-5C07-4C47-8B66-DCDA9BE58D54', datetime.datetime(2009, 2, 12, 0, 0)),
#  (152, 'EM', False, None, 'Yuhong', 'L', 'Li', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '866472D1-65C3-4AA7-B15B-F75EF10CB7D8', datetime.datetime(2009, 1, 25, 0, 0)),
#  (153, 'EM', False, None, 'Hanying', 'P', 'Feng', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'DDAAE515-0A69-4750-B6EE-7AC6629F55B8', datetime.datetime(2008, 12, 9, 0, 0)),
# ...
#  (1627, 'VC', False, 'Ms.', 'Cheryl', 'J.', 'Pompa', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '72AA1279-0197-437C-9C72-7018BE862576', datetime.datetime(2011, 12, 23, 0, 0)),
#  (1629, 'VC', False, None, 'Alma', 'B.', 'Poorbaugh', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '9D8FAF5F-8B8D-4DA0-948A-3E802D42F16E', datetime.datetime(2012, 2, 2, 0, 0)),
#  (1631, 'VC', False, 'Ms.', 'Ethel', 'J.', 'Porter', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '1E28BDD0-5C2B-4DCB-8B21-826D61C8853A', datetime.datetime(2012, 2, 2, 0, 0)),
#  (1633, 'VC', False, 'Ms.', 'Constance', 'J.', 'Posner', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '6E2624C6-8C4D-4A3E-A7C3-44685104F00B', datetime.datetime(2011, 5, 9, 0, 0)),
#  (1635, 'VC', False, 'Mr.', 'Josh', None, 'Pollock', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '58BCA248-2FA8-49A8-A159-EF1E0B80DBDA', datetime.datetime(2012, 1, 17, 0, 0)),
#  (1637, 'VC', False, 'Ms.', 'Betty', 'J.', 'Potts', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '2CEDCB06-6574-4192-9AEF-B2A7614A5CA0', datetime.datetime(2012, 1, 25, 0, 0)),
#  (1639, 'VC', False, 'Mr.', 'Fred', None, 'Preston', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'AD8DC1B2-D487-496D-974E-B9134719A209', datetime.datetime(2012, 2, 2, 0, 0)),
#  (1641, 'VC', False, 'Mr.', 'Jeff', None, 'Price', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'DA26B021-97BB-4057-8FA8-98EBBAC63387', datetime.datetime(2012, 2, 2, 0, 0)),
#  (1643, 'VC', False, 'Mr.', 'Milton', 'M.', 'Pugh', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '6C3A8F48-0E60-4A5D-BAD6-AC7E918BB67D', datetime.datetime(2012, 1, 25, 0, 0)),
#  (1645, 'VC', False, 'Mr.', 'Sean', None, 'Purcell', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'D060FE0A-41FF-414D-A861-5E11A982E27D', datetime.datetime(2012, 1, 17, 0, 0)),
#  (1647, 'VC', False, 'Ms.', 'Monica', 'L.', 'Quintana', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '21DE8320-AB5A-4953-B865-5E07C37E6B8F', datetime.datetime(2012, 1, 17, 0, 0)),
#  (1649, 'VC', False, 'Ms.', 'Mary Lou', 'M.', 'Quintana', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '4D5173FB-4356-47D9-B0CB-195ABC60F3FA', datetime.datetime(2011, 4, 25, 0, 0)),
#  (1651, 'VC', False, 'Ms.', 'Kim', None, 'Ralls', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'EF5AE74D-A030-4A80-B6D1-987B5EB5C102', datetime.datetime(2012, 2, 18, 0, 0)),
#  (1653, 'VC', False, 'Ms.', 'Susan', 'J.', 'Ramos', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'C8606945-354C-49FE-8152-2733276CD554', datetime.datetime(2011, 5, 9, 0, 0)),
#  (1655, 'VC', False, 'Ms.', 'Cynthia', None, 'Randall', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '2A6B008C-6D3A-465C-A2A5-6A57C6A50E9F', datetime.datetime(2012, 2, 2, 0, 0)),
#  (1657, 'VC', False, 'Mr.', 'Arvind', 'B.', 'Rao', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'ECC9CB33-8355-4602-BF7C-E0EA5F2E5867', datetime.datetime(2011, 12, 24, 0, 0)),
#  (1659, 'VC', False, 'Mr.', 'Simon', None, 'Rapier', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'C373DAE2-8BF2-4CA6-9AE9-37763692A0E2', datetime.datetime(2012, 1, 25, 0, 0)),
#  (1661, 'VC', False, 'Mr.', 'Michael', 'S', 'Ray', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '181F0FB6-6B52-44DF-A11F-24ABEE092248', datetime.datetime(2012, 2, 2, 0, 0)),
#  (1663, 'VC', False, 'Ms.', 'Suzann', 'K.', 'Reams', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'D47E35E9-FCFE-4BF6-A6C0-8061A65A751F', datetime.datetime(2011, 5, 9, 0, 0)),
#  (1665, 'VC', False, 'Ms.', 'Michelle', 'B.', 'Rector', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '589F7370-661E-4E6E-9493-47D50E468679', datetime.datetime(2012, 1, 29, 0, 0)),
#  (1667, 'VC', False, 'Ms.', 'Jamie', None, 'Reding', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'C116CFB9-724F-4223-BF0A-685015A7CCDD', datetime.datetime(2012, 2, 3, 0, 0)),
#  (1669, 'VC', False, 'Mr.', 'Russell', 'A.', 'Reed', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '3A35179A-0DC4-4A42-919E-BC162F72F1FE', datetime.datetime(2012, 2, 3, 0, 0)),
#  (1671, 'VC', False, 'Ms.', 'Celine', 'J.', 'Reed', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '7EC9892F-DD0C-4E1D-98AA-0BF3EF7B41AF', datetime.datetime(2012, 1, 25, 0, 0)),
#  (1673, 'VC', False, 'Mr.', 'Randy', None, 'Reeves', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '4DA9BF5D-10CB-468F-991C-03F2A823E19E', datetime.datetime(2012, 2, 18, 0, 0)),
#  (1675, 'VC', False, 'Mr.', 'Enoch', 'T', 'Remick', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'E4F14635-F2E9-4688-A41E-DC8F1EAD6D76', datetime.datetime(2012, 2, 3, 0, 0)),
#  (1677, 'VC', False, 'Mr.', 'Eric', 'E.', 'Rhodes', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'B4DA7B01-A4DF-40AE-AE97-2BF09B1DDE27', datetime.datetime(2011, 5, 9, 0, 0)),
#  (1679, 'VC', False, 'Mr.', 'Adam', 'J.', 'Reynolds', 'Jr.', 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'BC4E0302-33E6-4897-995E-9994BEBFAEB6', datetime.datetime(2012, 1, 25, 0, 0)),
#  (1681, 'VC', False, 'Ms.', 'Constance', 'J.', 'Remmington', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '9666C77B-66C6-42D2-9CFF-00ACDE4C2D84', datetime.datetime(2012, 2, 2, 0, 0)),
#  (1683, 'VC', False, 'Mr.', 'Albert', 'A.', 'Rhodes', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'EDF54CFC-7B97-49CF-8EE9-1059524C533F', datetime.datetime(2012, 2, 2, 0, 0)),
#  (1685, 'VC', False, 'Mr.', 'Dave', None, 'Richards', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '01BEC60C-8E17-4C63-A787-2245E92A8845', datetime.datetime(2012, 2, 2, 0, 0)),
#  (1687, 'VC', False, 'Mr.', 'Jack', 'S.', 'Richins', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '0D3B502B-EF37-465F-BEC4-08A6B443AD19', datetime.datetime(2012, 2, 18, 0, 0)),
#  (1689, 'VC', False, 'Ms.', 'Marie', 'M.', 'Richmeier', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', 'FBC9DAAF-4436-4281-AE9C-AC782002A175', datetime.datetime(2011, 12, 23, 0, 0)),
#  (1691, 'VC', False, 'Mr.', 'William', 'J.', 'Richter', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '5F7E4156-1989-4E99-8574-C5F05A887DCF', datetime.datetime(2011, 12, 24, 0, 0)),
#  (1693, 'VC', False, 'Mr.', 'Thomas', 'M.', 'Richards', 'Jr.', 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '9DFD05F3-6BFB-45C1-942F-1D3EC141D39F', datetime.datetime(2011, 12, 24, 0, 0)),
#  (1695, 'VC', False, 'Ms.', 'Stacy', 'K.', 'Rizzi', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '2130ED19-EFF9-4006-B4C0-CAF5BA579D0A', datetime.datetime(2011, 12, 24, 0, 0)),
#  (1697, 'VC', False, 'Ms.', 'Leota', 'J.', 'Roberts', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>', '071BA803-57A8-439F-9DAE-5695052649B6', datetime.datetime(2011, 12, 23, 0, 0)),
#  (1699, 'IN', False, 'Mr.', 'David', 'R.', 'Robinett', None, 1, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>-16.01</TotalPurchaseYTD><DateFirstPurchase>2003-09-01Z</DateFirstPurchase><BirthDate>1961-02-23Z</BirthDate><MaritalStatus>M</MaritalStatus><YearlyIncome>25001-50000</YearlyIncome><Gender>M</Gender><TotalChildren>4</TotalChildren><NumberChildrenAtHome>0</NumberChildrenAtHome><Education>Graduate Degree</Education><Occupation>Clerical</Occupation><HomeOwnerFlag>1</HomeOwnerFlag><NumberCarsOwned>0</NumberCarsOwned><CommuteDistance>0-1 Miles</CommuteDistance></IndividualSurvey>', '7893C62D-9940-4DB8-90D4-EA0CCD9F6731', datetime.datetime(2013, 7, 31, 0, 0)),
#  (1700, 'IN', False, 'Ms.', 'Rebecca', 'A.', 'Robinson', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>-4</TotalPurchaseYTD><DateFirstPurchase>2004-06-05Z</DateFirstPurchase><BirthDate>1965-06-11Z</BirthDate><MaritalStatus>M</MaritalStatus><YearlyIncome>50001-75000</YearlyIncome><Gender>F</Gender><TotalChildren>3</TotalChildren><NumberChildrenAtHome>3</NumberChildrenAtHome><Education>Bachelors </Education><Occupation>Professional</Occupation><HomeOwnerFlag>1</HomeOwnerFlag><NumberCarsOwned>1</NumberCarsOwned><CommuteDistance>5-10 Miles</CommuteDistance></IndividualSurvey>', '1B81EF06-05C2-4D27-960F-4455938CB255', datetime.datetime(2014, 5, 5, 0, 0)),
#  (1701, 'IN', False, 'Ms.', 'Dorothy', 'B.', 'Robinson', None, 2, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>4730.04</TotalPurchaseYTD><DateFirstPurchase>2002-04-07Z</DateFirstPurchase><BirthDate>1954-09-23Z</BirthDate><MaritalStatus>S</MaritalStatus><YearlyIncome>75001-100000</YearlyIncome><Gender>M</Gender><TotalChildren>2</TotalChildren><NumberChildrenAtHome>0</NumberChildrenAtHome><Education>Partial College</Education><Occupation>Skilled Manual</Occupation><HomeOwnerFlag>0</HomeOwnerFlag><NumberCarsOwned>2</NumberCarsOwned><CommuteDistance>1-2 Miles</CommuteDistance></IndividualSurvey>', 'FED4A110-8137-4AA5-8B27-A15B4147D7C4', datetime.datetime(2012, 3, 6, 0, 0)),
#  (1702, 'IN', False, 'Ms.', 'Carol Ann', 'F.', 'Rockne', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>2435.4018</TotalPurchaseYTD><DateFirstPurchase>2001-10-27Z</DateFirstPurchase><BirthDate>1943-07-15Z</BirthDate><MaritalStatus>M</MaritalStatus><YearlyIncome>25001-50000</YearlyIncome><Gender>M</Gender><TotalChildren>1</TotalChildren><NumberChildrenAtHome>0</NumberChildrenAtHome><Education>Bachelors </Education><Occupation>Clerical</Occupation><HomeOwnerFlag>1</HomeOwnerFlag><NumberCarsOwned>0</NumberCarsOwned><CommuteDistance>0-1 Miles</CommuteDistance></IndividualSurvey>', '1DCFABA9-41F7-4C95-8CF4-7C9FBA398C6B', datetime.datetime(2011, 9, 26, 0, 0)),
#  (1703, 'IN', False, 'Mr.', 'Scott', 'M.', 'Rodgers', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>1647</TotalPurchaseYTD><DateFirstPurchase>2002-04-18Z</DateFirstPurchase><BirthDate>1968-05-15Z</BirthDate><MaritalStatus>M</MaritalStatus><YearlyIncome>50001-75000</YearlyIncome><Gender>M</Gender><TotalChildren>2</TotalChildren><NumberChildrenAtHome>2</NumberChildrenAtHome><Education>Bachelors </Education><Occupation>Professional</Occupation><HomeOwnerFlag>1</HomeOwnerFlag><NumberCarsOwned>1</NumberCarsOwned><CommuteDistance>2-5 Miles</CommuteDistance></IndividualSurvey>', '77C57B30-2394-4548-8246-3BEC69366142', datetime.datetime(2012, 3, 17, 0, 0)),
#  (1704, 'IN', False, 'Mr.', 'Jim', None, 'Rodman', None, 0, None, '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>-699.0964</TotalPurchaseYTD><DateFirstPurchase>2002-02-14Z</DateFirstPurchase><BirthDate>1955-09-13Z</BirthDate><MaritalStatus>M</MaritalStatus><YearlyIncome>greater than 100000</YearlyIncome><Gender>F</Gender><TotalChildren>3</TotalChildren><NumberChildrenAtHome>4</NumberChildrenAtHome><Education>Partial College</Education><Occupation>Professional</Occupation><HomeOwnerFlag>1</HomeOwnerFlag><NumberCarsOwned>3</NumberCarsOwned><CommuteDistance>5-10 Miles</CommuteDistance></IndividualSurvey>', '9F34A44B-148D-4A90-8E3D-824F786F995F', datetime.datetime(2012, 1, 14, 0, 0)),
#  ...]

# %%
# Create Operation
query1 = "Create table AmazonProducts(ProductId int, ProductName varchar(200),Cost int)"
cursor = conn.cursor();
cursor.execute(query1);

# %%
#Read Operation
query2 ="Select * from AmazonProducts"
cursor.execute(query2);
data1 = cursor.fetchall()
data1
# Out:
# []

# %%
# insert Operation
query3 ="insert into AmazonProducts values (1,'Bag', 150)"
query4="insert into AmazonProducts values (2,'Pen', 25)"
query5 ="insert into AmazonProducts values (3,'Book', 300)"
cursor.execute(query3)
cursor.execute(query4)
cursor.execute(query5)

# %%
#Read Operation
query2 ="Select * from AmazonProducts"
cursor.execute(query2);
data1 = cursor.fetchall()
data1
# Out:
# [(1, 'Bag', 150), (2, 'Pen', 25), (3, 'Book', 300)]

# %%
# Update Operation
query7="update AmazonProducts set Cost=120 where ProductId=1 "
cursor.execute(query7)
query8 ="Select * from AmazonProducts"
cursor.execute(query8);
data2 = cursor.fetchall()
data2
# Out:
# [(1, 'Bag', 120), (2, 'Pen', 25), (3, 'Book', 300)]

# %%
# Delete Operation
query9 = "delete from AmazonProducts where ProductId=3"
cursor.execute(query9);
query10 ="Select * from AmazonProducts"
cursor.execute(query10);
data3 = cursor.fetchall()
data3
# Out:
# [(1, 'Bag', 120), (2, 'Pen', 25)]
